# %%
import pandas as pd
from reading import read_config_file

# %%
data1 = pd.read_csv(r'D:\repos\digitalhack\scripts\data\plantsdata\data_0.0.1.csv', index_col=0)

# %%
data2 = pd.read_csv(r'D:\repos\digitalhack\scripts\data\plantsdata\data_0.0.2.csv', index_col=0)

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres:zxcasdqwe123@localhost:5432/PlantsData')
# Out:
# 162

# %%
# data1.to_sql('plants_atlas_1', engine)

# %%
# data2.to_sql('plants_atlas_2', engine)

# %%
data01 = pd.read_csv(r'D:\repos\digitalhack\scripts\data\plantsdata\data_0.1.0.csv', index_col=0)

# %%
data011 = pd.read_csv(r'D:\repos\digitalhack\scripts\data\plantsdata\data_0.1.1.csv', index_col=0)

# %%
data011 = data011.fillna('')

# %%
data012 = pd.read_csv(r'D:\repos\digitalhack\scripts\data\plantsdata\data_0.1.3.csv', index_col=0)

# %%
data012
# Out:
#                          name
# 0    Аденостилес Ромболистный  \
# 1            Аир Обыкновенный
# 2            Алоэ Древовидное
# 3         Алтей Лекарственный
# 4                Амми Большая
# ..                        ...
# 176      Эвкоммия Вязолистная
# 177           Эрва Шерстистая
# 178           Эфедра Хвощевая
# 179        Эхинацея Пурпурная
# 180         Якорцы Стелющиеся
#
#                                              data_capt
# 0    Описание. Травянистый многолетник высотой  50-...  \
# 1    Описание. Многолетнее травянистое однодольное ...
# 2    Описание. Суккулентный кустарник высотой до  5...
# 3    Описание. Многолетнее серовато -зеленое травя ...
# 4    Описание.  Однолетнее  или двулетнее  травянис...
# ..                                                 ...
# 176  Описание. Небольшое листопадное двудомное (оче...
# 177  Описание.  Многолетнее  травянистое  растение ...
# 178  Описание.  Вечнозеленый,  двудомный,  сильнове...
# ...
